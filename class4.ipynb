# %% [markdown]
# <a href="https://colab.research.google.com/github/saikumar1-code/python-CRT/blob/main/class4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# materialistic
# realistic

# %%
a=input("enter cute boy name")
b=input("enter second name")

name1_chars = list(a.replace(" ", "").lower())
name2_chars = list(b.replace(" ", "").lower())

temp_name1 = list(name1_chars)
temp_name2 = list(name2_chars)

for char in name1_chars:
    if char in temp_name2:
        temp_name1.remove(char)
        temp_name2.remove(char)

cnt = len(temp_name1) + len(temp_name2)

if cnt == 0:
    cnt = 6

index = 0
res = list("FLAMES")

for _ in range(5):
    index = (index + (cnt - 1)) % len(res)
    res.pop(index)

print(res[0])

# %%
cnt=6
res=[1,2,3,4,5,6]
i=0
i=(i)

# %%
index=0
res=list("FLAMES")
for i in range(5):
  index=index(index+(cnt-1))%len(res)
  res.pop(index)
print(res[0])

# %%
print(a1)
print(b1)
cnt=0
for i in a1:
  if

# %%
res=[]
res.append(nums[0])

for i in range(1,len(nums)):
  d=res[-1+num[i]]

# %%
a=[[" " for i in range(11)] for i in range(11)]

for i in range(11):
    for j in range(11):
        if j==0 or j==10:
            a[i][j]="*"
        if i==j and i<6:
           a[i][j]="*"
        if i+j==10 and i<6:
            a[i][j]="*"

for i in range(11):
    for j in range(11):
        print(a[i][j],end=" ")
    print()
# Out:
# *                   *
# * *               * *
# *   *           *   *
# *     *       *     *
# *       *   *       *
# *         *         *
# *                   *
# *                   *
# *                   *
# *                   *
# *                   *

# %%
a={23,4,5,6}
for i in a:
    print("hi")
# Out:
# hi
# hi
# hi
# hi

# %%
a={23,4,5,6}
a.add(90)
print(a)
# Out:
# {4, 5, 6, 23, 90}

# %%
a={2,3,4,5}
a.pop()
print(a)
# Out:
# {3, 4, 5}

# %%
a={2,3,4,5}
a.remove(3)
print(a)
# Out:
# {2, 4, 5}

# %%
a={2,3,4,5}
a.add(100)
print(a)
# Out:
# {2, 3, 100, 4, 5}

# %%
a={2,4,6,7,8,9}
b={1,2,4,7,11,13}
print(a.union(b))
print(a&b)
print(a.intersection(b))
print(a^b)
print(a-b)
print(a.difference(b))
print(a.symmetric_difference(b))
# Out:
# {1, 2, 4, 6, 7, 8, 9, 11, 13}
# {2, 4, 7}
# {2, 4, 7}
# {1, 6, 8, 9, 11, 13}
# {8, 9, 6}
# {8, 9, 6}
# {1, 6, 8, 9, 11, 13}

# %%
a={2,4,6,7,9,(1,2,3)}
print(a)
# Out:
# {2, 4, 6, 7, 9, (1, 2, 3)}

# %%
d={'name':'gill','age':45,'rusn':4000}
for i in d.items():
    print(i)
for i in d.keys():
    print(i)
# Out:
# ('name', 'gill')
# ('age', 45)
# ('rusn', 4000)
# name
# age
# rusn

# %%
d={'name':'gill','age':45,'rusn':4000}
d['marks']=[2,3,4,5]
print(d['marks'][1])
# Out:
# 3

# %%
a=int(input("Ishitha Enter any num:"))
nums=[]
while(True):
  if a==1:
      break
  elif a in nums:
      break
  else:
      nums.append(a)
      a=sum([int(i)*int(i) for i in str(a)])
      nums.append(a)
      a=b
if a==1:
    print("round")
else:
# Out:
#   File "/tmp/ipykernel_4127/1438491093.py", line 15
#     else:
#          ^
# SyntaxError: incomplete input
